# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import csv
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver import ActionChains
import os
from urllib.request import urlretrieve
from selenium.common.exceptions import NoSuchElementException
img_list=[]
name_list = []
price_list = []
contents_list = []
ptype_list = []
comp_list = []
target_list=[
            'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=49',
            'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=51',
             'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=50',
             'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=52',
             'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=77',
             'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=80',
             'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=83',
             'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=12',
        'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=127',
        'https://www.naturecollection.com/mall/product/category.jsp?cate_seq=128'
            ]
driver = wb.Chrome(ChromeDriverManager().install())
for j in target_list:
    driver.get(j)
    driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.END)
    time.sleep(1)
#     driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.PAGE_DOWN)
#     time.sleep(1)
#     driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.PAGE_DOWN)
#     time.sleep(1)
#     driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.PAGE_DOWN)
#     time.sleep(1)
    try:
        driver.find_element(By.CSS_SELECTOR,'#addProductEle > a').click()
        driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
        driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
    except:
        pass
    temp_list=driver.find_elements(By.CSS_SELECTOR,'#prdtList > li> div.img > img')
    for i in range(len(temp_list)):
        driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.END)
        time.sleep(1)
        try:
            driver.find_element(By.CSS_SELECTOR,'#addProductEle > a').click()
        except:
            pass
        temp_list=driver.find_elements(By.CSS_SELECTOR,'#prdtList > li> div.img > img')
        temp_list[i].click()
        temp_name=driver.find_element(By.CSS_SELECTOR,'#optionProdList > div.box1 > a').text
        if '더페이스샵' == temp_name:
            name_list.append(driver.find_element(By.CSS_SELECTOR,'#optionProdList > div.box1 > p').text)
            img_list.append(driver.find_element(By.CSS_SELECTOR,'body > div.RootDiv > div.MallDiv > section > div > div.prdHead > div > div > div.zoom_img > img').get_attribute('src'))
            price_list.append(driver.find_element(By.CSS_SELECTOR,'#optionProdList > div.box1 > div.prd_price > strong > span').text)
            temp_ptype_list=driver.find_elements(By.CSS_SELECTOR,'#optionProdList > div.box1 > div.effect > ul > li')
            temp2_ptype_list=[]
            for i in temp_ptype_list:
                temp2_ptype_list.append(i.text)
            result=",".join(temp2_ptype_list)
            ptype_list.append(result)
            driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.PAGE_DOWN)
            driver.find_element(By.CSS_SELECTOR,'body').send_keys(Keys.PAGE_DOWN)
            time.sleep(1)
            try:
                contents_list.append(driver.find_element(By.CSS_SELECTOR,'body > div.RootDiv > div.MallDiv > section > div > div.product_detailview > p > img').get_attribute('src'))
            except:
                try:
                    contents_list.append(driver.find_element(By.CSS_SELECTOR,'body > div.RootDiv > div.MallDiv > section > div > div.product_detailview > div > img').get_attribute('src'))
                except:
                    contents_list.append('인간크롤링필요')
            time.sleep(1)
            driver.find_element(By.CSS_SELECTOR,'body > div.RootDiv > div.MallDiv > section > div > div.category_wrap > ul > li:nth-child(2) > a > span.v_center').click()
#             ptype_list.append(driver.find_element(By.CSS_SELECTOR,'#specInfoLayer > tr:nth-child(2) > td').text)
#             time.sleep(1)
            comp_list.append(driver.find_element(By.CSS_SELECTOR,'#specInfoLayer > tr:nth-child(6) > td').text)
            driver.back()
            driver.back()
            time.sleep(1)
        else:
            driver.back()
            time.sleep(1)
# Out:
# C:\Users\pipi1\AppData\Local\Temp\ipykernel_6824\3669112439.py:33: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome(ChromeDriverManager().install())

# %%
name_list
# Out:
# ['치아씨드 수분 토너',
#  '더테라피 에센셜 토닉 트리트먼트',
#  '더테라피 수분 토닉 트리트먼트',
#  '라이스&세라마이드 모이스처라이징 토너',
#  '망고씨드 보습 토너',
#  '더페이스샵 티트리 토너패드',
#  '카렌듈라 에센셜 모이스처 토너',
#  '더테라피 비건 블렌딩 토너',
#  '화이트씨드 리얼 미백 토너',
#  '[더페이스샵 X 어프어프] 티트리 토너패드',
#  '석류 엔 콜라겐 볼륨탄력 토너',
#  '더테라피 오일드롭 항노화 세럼',
#  '아르쌩뜨 에코-테라피 토닉 위드 에센셜 (대용량)',
#  '석류 엔 콜라겐 볼륨탄력 에센스',
#  '더테라피 수분드롭 항노화 세럼',
#  '더테라피 퍼스트 세럼',
#  '화이트씨드 리얼 미백 에센스',
#  '더페이스샵 티트리 모공 앰플',
#  '아르쌩뜨 에코-테라피 모이스춰라이저',
#  '치아씨드 수분 로션',
#  '망고씨드 보습 로션',
#  '라이스&세라마이드 모이스처라이징 에멀전',
#  '더테라피 수분 포뮬러 에멀젼',
#  '더테라피 에센셜 포뮬러 에멀젼',
#  '화이트씨드 리얼 미백 로션',
#  '카렌듈라 에센셜 모이스처 에멀전',
#  '석류 엔 콜라겐 볼륨탄력 에멀젼',
#  '더테라피 로얄 메이드 오일 블렌딩 크림 스페셜 세트',
#  '치아씨드 수분 크림',
#  '망고씨드 보습 버터',
#  '더테라피 로얄메이드 수분블렌딩 크림',
#  '더테라피 로얄메이드 오일 블렌딩 크림',
#  '석류 엔 콜라겐 볼륨탄력 크림',
#  '라이스&세라마이드 모이스처라이징 크림',
#  '더테라피 비건 블렌딩 크림',
#  '더테라피 비건 블렌딩 멀티밤',
#  '티트리 모공 크림',
#  '더페이스샵 X 어프어프 신선한 제주 알로에 수딩젤',
#  '미감수 브라이트 페이셜 클렌징 폼',
#  '미감수 브라이트 페이셜 쌀겨 클렌징 폼',
#  '미감수 브라이트 페이셜 클렌징 폼 (대용량)',
#  '허브데이 아미노산 비건 폼(작약/알로에)',
# ...

# %%
name_list[89]
# Out:
# '스피프코드 내추럴 톤업 크림 50ml'

# %%
import pandas as pd
data={'name':name_list,'price':price_list,'contents':contents_list,'ptype':ptype_list,'comp':comp_list}
df=pd.DataFrame(data)
df
# Out:
#                     name    price  \
# 0             치아씨드 수분 토너  17,000원
# 1      더테라피 에센셜 토닉 트리트먼트  27,000원
# 2       더테라피 수분 토닉 트리트먼트  27,000원
# 3   라이스&세라마이드 모이스처라이징 토너   8,500원
# 4             망고씨드 보습 토너  19,000원
# ..                   ...      ...
# 85   네오클래식 옴므 블랙 에센셜 에멀젼  25,000원
# 86        더젠틀포맨 안티에이징 스킨  22,000원
# 87              더 블랙밤 로션  25,000원
# 88              더 블랙밤 스킨  25,000원
# 89  스피프코드 내추럴 톤업 크림 50ml  18,000원
#
#                                              contents  \
# 0   https://image.ethefaceshop.com/tfsshopWebSrc/u...
# 1   https://image.ethefaceshop.com/tfsshopWebSrc/u...
# 2   https://image.ethefaceshop.com/tfsshopWebSrc/u...
# 3   https://image.ethefaceshop.com/tfsshopWebSrc/u...
# 4   https://image.ethefaceshop.com/tfsshopWebSrc/u...
# ..                                                ...
# 85  https://image.ethefaceshop.com/tfsshopWebSrc/u...
# 86  https://image.ethefaceshop.com/tfsshopWebSrc/u...
# 87  https://image.ethefaceshop.com/tfsshopWebSrc/u...
# ...

# %%
p_list=[]
for i in price_list:
    new_str = i.replace(',', '')[0:-1]
    
    p = int(new_str)
    p_list.append(p)

# %%
p_list
# Out:
# [17000,
#  27000,
#  27000,
#  8500,
#  19000,
#  28000,
#  13000,
#  28000,
#  20000,
#  28000,
#  18000,
#  30000,
#  18000,
#  22000,
#  30000,
#  30000,
#  25000,
#  30000,
#  14000,
#  17000,
#  19000,
#  8500,
#  24000,
#  24000,
#  20000,
#  13000,
#  18000,
#  38000,
#  26000,
#  28000,
#  38000,
#  38000,
#  22000,
#  9500,
#  30400,
#  14000,
#  28000,
#  4500,
#  8500,
#  9500,
#  12000,
#  12000,
#  11000,
#  5500,
#  11000,
#  11000,
#  14000,
#  11000,
#  13000,
#  8500,
#  4500,
#  16500,
#  3800,
#  10000,
#  3800,
#  15000,
#  12000,
#  12000,
#  19000,
#  20000,
#  11000,
#  14000,
#  19000,
#  15000,
#  36000,
#  27000,
#  19000,
#  16000,
#  19000,
#  22000,
#  22000,
#  16000,
#  16000,
#  20000,
#  16000,
#  20000,
#  22000,
#  24000,
#  14000,
#  26000,
#  19000,
#  20000,
#  20000,
#  22000,
#  25000,
#  25000,
#  22000,
#  25000,
#  25000,
#  18000]

# %%
import pymysql
# mysql 연결
conn = pymysql.connect(host='project-db-stu.ddns.net', port=3307, user='gjaischool', passwd='1234', db='gjaischool', charset='utf8')
# 실행 결과 데이터를 담을 메모리 객체
cursor = conn.cursor()

# sql로 던지기
sql = "INSERT INTO cosmetics (cos_name, cos_price,cos_ingredient,cos_photo1,cos_photo2,cos_type) VALUES(%s,%s,%s,%s,%s,%s)"
# 튜플형식으로 만들기
val = []
d=[]
for i in range(90):
    d =tuple( [name_list[i],p_list[i],comp_list[i],img_list[i],contents_list[i],pt_list[i]])
    val.append(d)
# insert한번에 다 넣으려면 executemany 사용해야함    
cursor.executemany(sql,val)
cursor.execute("commit")
print(cursor.rowcount,'commit')
# Out:
# 0 commit

# %%
ptype_list
# Out:
# ['수분/보습,모든피부용',
#  '모든피부용,주름개선/탄력,수분/보습,영양공급',
#  '모든피부용,주름개선/탄력,수분/보습',
#  '수분/보습',
#  '수분/보습,영양공급',
#  '피지/모공,각질',
#  '수분/보습,영양공급,모든피부용',
#  '수분/보습,주름개선/탄력,모든피부용',
#  '미백,수분/보습',
#  '피지/모공',
#  '주름개선/탄력,수분/보습,영양공급',
#  '모든피부용,수분/보습,주름개선/탄력,영양공급',
#  '수분/보습,영양공급,건성,모든피부용',
#  '주름개선/탄력,수분/보습,영양공급',
#  '모든피부용,주름개선/탄력,수분/보습',
#  '주름개선/탄력,수분/보습,영양공급',
#  '미백,수분/보습',
#  '',
#  '모든피부용,수분/보습',
#  '수분/보습,모든피부용',
#  '수분/보습,영양공급',
#  '모든피부용,수분/보습,영양공급',
#  '주름개선/탄력,수분/보습',
#  '모든피부용,주름개선/탄력,수분/보습,영양공급',
#  '미백,수분/보습',
#  '수분/보습,영양공급,모든피부용',
#  '주름개선/탄력,수분/보습,영양공급',
#  '주름개선/탄력,수분/보습,영양공급',
#  '수분/보습,모든피부용',
#  '수분/보습,영양공급',
#  '주름개선/탄력,수분/보습,영양공급',
#  '주름개선/탄력,수분/보습,영양공급',
#  '주름개선/탄력,수분/보습,영양공급',
#  '수분/보습',
#  '수분/보습,주름개선/탄력,모든피부용',
#  '수분/보습,모든피부용',
#  '',
#  '수분/보습',
#  '모든피부용,피부톤',
#  '모든피부용,피부톤,각질',
#  '모든피부용,피부톤',
#  '',
#  '수분/보습,모든피부용',
#  '모든피부용',
#  '피지/모공,모든피부용',
#  '모든피부용,미백,수분/보습',
#  '수분/보습,모든피부용',
#  '피지/모공,모든피부용',
#  '수분/보습',
#  '',
#  '수분/보습,모든피부용',
#  '모든피부용',
#  '',
# ...

# %%
name_list
# Out:
# ['치아씨드 수분 토너',
#  '더테라피 에센셜 토닉 트리트먼트',
#  '더테라피 수분 토닉 트리트먼트',
#  '라이스&세라마이드 모이스처라이징 토너',
#  '망고씨드 보습 토너',
#  '더페이스샵 티트리 토너패드',
#  '카렌듈라 에센셜 모이스처 토너',
#  '더테라피 비건 블렌딩 토너',
#  '화이트씨드 리얼 미백 토너',
#  '[더페이스샵 X 어프어프] 티트리 토너패드',
#  '석류 엔 콜라겐 볼륨탄력 토너',
#  '더테라피 오일드롭 항노화 세럼',
#  '아르쌩뜨 에코-테라피 토닉 위드 에센셜 (대용량)',
#  '석류 엔 콜라겐 볼륨탄력 에센스',
#  '더테라피 수분드롭 항노화 세럼',
#  '더테라피 퍼스트 세럼',
#  '화이트씨드 리얼 미백 에센스',
#  '더페이스샵 티트리 모공 앰플',
#  '아르쌩뜨 에코-테라피 모이스춰라이저',
#  '치아씨드 수분 로션',
#  '망고씨드 보습 로션',
#  '라이스&세라마이드 모이스처라이징 에멀전',
#  '더테라피 수분 포뮬러 에멀젼',
#  '더테라피 에센셜 포뮬러 에멀젼',
#  '화이트씨드 리얼 미백 로션',
#  '카렌듈라 에센셜 모이스처 에멀전',
#  '석류 엔 콜라겐 볼륨탄력 에멀젼',
#  '더테라피 로얄 메이드 오일 블렌딩 크림 스페셜 세트',
#  '치아씨드 수분 크림',
#  '망고씨드 보습 버터',
#  '더테라피 로얄메이드 수분블렌딩 크림',
#  '더테라피 로얄메이드 오일 블렌딩 크림',
#  '석류 엔 콜라겐 볼륨탄력 크림',
#  '라이스&세라마이드 모이스처라이징 크림',
#  '더테라피 비건 블렌딩 크림',
#  '더테라피 비건 블렌딩 멀티밤',
#  '티트리 모공 크림',
#  '더페이스샵 X 어프어프 신선한 제주 알로에 수딩젤',
#  '미감수 브라이트 페이셜 클렌징 폼',
#  '미감수 브라이트 페이셜 쌀겨 클렌징 폼',
#  '미감수 브라이트 페이셜 클렌징 폼 (대용량)',
#  '허브데이 아미노산 비건 폼(작약/알로에)',
# ...

# %%
pt_list=[]
for i in ptype_list:
    if i=='':
        i='모든피부'
    pt_list.append(i)

# %%
pt_list
# Out:
# ['수분/보습,모든피부용',
#  '모든피부용,주름개선/탄력,수분/보습,영양공급',
#  '모든피부용,주름개선/탄력,수분/보습',
#  '수분/보습',
#  '수분/보습,영양공급',
#  '피지/모공,각질',
#  '수분/보습,영양공급,모든피부용',
#  '수분/보습,주름개선/탄력,모든피부용',
#  '미백,수분/보습',
#  '피지/모공',
#  '주름개선/탄력,수분/보습,영양공급',
#  '모든피부용,수분/보습,주름개선/탄력,영양공급',
#  '수분/보습,영양공급,건성,모든피부용',
#  '주름개선/탄력,수분/보습,영양공급',
#  '모든피부용,주름개선/탄력,수분/보습',
#  '주름개선/탄력,수분/보습,영양공급',
#  '미백,수분/보습',
#  '모든피부',
#  '모든피부용,수분/보습',
#  '수분/보습,모든피부용',
#  '수분/보습,영양공급',
#  '모든피부용,수분/보습,영양공급',
#  '주름개선/탄력,수분/보습',
#  '모든피부용,주름개선/탄력,수분/보습,영양공급',
#  '미백,수분/보습',
#  '수분/보습,영양공급,모든피부용',
#  '주름개선/탄력,수분/보습,영양공급',
#  '주름개선/탄력,수분/보습,영양공급',
#  '수분/보습,모든피부용',
#  '수분/보습,영양공급',
#  '주름개선/탄력,수분/보습,영양공급',
#  '주름개선/탄력,수분/보습,영양공급',
#  '주름개선/탄력,수분/보습,영양공급',
#  '수분/보습',
#  '수분/보습,주름개선/탄력,모든피부용',
#  '수분/보습,모든피부용',
#  '모든피부',
#  '수분/보습',
#  '모든피부용,피부톤',
#  '모든피부용,피부톤,각질',
#  '모든피부용,피부톤',
#  '모든피부',
#  '수분/보습,모든피부용',
#  '모든피부용',
#  '피지/모공,모든피부용',
#  '모든피부용,미백,수분/보습',
#  '수분/보습,모든피부용',
#  '피지/모공,모든피부용',
#  '수분/보습',
#  '모든피부',
#  '수분/보습,모든피부용',
# ...

# %%
# 화장품 번호 두개씩 넣기
cos_seq=[]
gubun_name=[]
gubun_value=[]
gubun_depth=[]
for i in range(1,91):
    a=i
    cos_seq.append(i)
    cos_seq.append(i)

# %%
# 더페이스샵 90개 상품 두번씩 들어가니까 180번 
gubun_name=[]
for i in range(180):
    gubun_name.append('더페이스샵')

# %%
gubun_value=[]
gubun_depth=[]
for i in range(11):
    gubun_value.append('스킨케어')
    gubun_depth.append(1)
    gubun_value.append('토너')
    gubun_depth.append(2)

# %%
for i in range(18):
    gubun_value.append('썬크림')
    gubun_depth.append(1)
    gubun_value.append('썬크림')
    gubun_depth.append(2)

# %%
for i in range(1):
    gubun_value.append('남성')
    gubun_depth.append(1)
    gubun_value.append('토너')
    gubun_depth.append(2)

# %%
for i in range(1):
    gubun_value.append('남성')
    gubun_depth.append(1)
    gubun_value.append('로션')
    gubun_depth.append(2)

# %%
for i in range(1):
    gubun_value.append('남성')
    gubun_depth.append(1)
    gubun_value.append('에센스')
    gubun_depth.append(2)

# %%
len(gubun_value)
# Out:
# 180

# %%
import pymysql
# mysql 연결
conn = pymysql.connect(host='project-db-stu.ddns.net', port=3307, user='gjaischool', passwd='1234', db='gjaischool', charset='utf8')
# 실행 결과 데이터를 담을 메모리 객체
cursor = conn.cursor()

# sql로 던지기
sql = "INSERT INTO category (cos_seq, gubun_name, gubun_value, gubun_depth) VALUES(%s,%s,%s,%s)"
# 튜플형식으로 만들기
val = []
d=[]
for i in range(180):
    d =tuple( [cos_seq[i],gubun_name[i],gubun_value[i],gubun_depth[i]] )
    val.append(d)
# insert한번에 다 넣으려면 executemany 사용해야함    
cursor.executemany(sql,val)
cursor.execute("commit")
print(cursor.rowcount,'commit')
# Out:
# 0 commit

# %%
gubun_value
# Out:
# ['스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '토너',
#  '스킨케어',
#  '에센스',
#  '스킨케어',
#  '에센스',
#  '스킨케어',
#  '에센스',
#  '스킨케어',
#  '에센스',
#  '스킨케어',
#  '에센스',
#  '스킨케어',
#  '에센스',
#  '스킨케어',
#  '에센스',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '로션',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '스킨케어',
#  '크림',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
#  '클렌징',
# ...

# %%
gubun_value[177]='토너'
